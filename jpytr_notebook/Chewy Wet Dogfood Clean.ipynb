# %% [markdown]
# # Cleaning of Scraped Data

# %%
import pandas as pd
import numpy as np
import re

# %%
wdog_csv_df = pd.read_csv('wetdogfood.csv')
print(wdog_csv_df.shape)
wdog_csv_df.head()
# Out:
# (1290, 24)
#    rating                        list_price weight          lifestage  \
# 0     4.4  \n                        $23.88    NaN  adult, all stages
# 1     4.6                               NaN    NaN              adult
# 2     4.9  \n                        $22.99    NaN              adult
# 3     4.6  \n                        $27.99    NaN              adult
# 4     4.6  \n                        $19.08    NaN              adult
#
#      protein                            caloric                 size  \
# 0   9.5% min  804 kcal/kg, 290 kcal/12.7 oz can                  NaN
# 1   2.5% min               330 kcal/12.5 oz can  12.5-oz, case of 12
# 2   4.5% min               329 kcal/12.8 oz can                  NaN
# 3  10.0% min        1,425 kcal/kg, 506 kcal/can                  NaN
# 4   8.0% min          954 kcal/kg, 338 kcal/can  12.5-oz, case of 12
#
#             category     fibre  review_count       ...         \
# 0  Dog,Food,Wet Food  1.4% max         206.0       ...
# 1  Dog,Food,Wet Food  2.0% max         175.0       ...
# 2  Dog,Food,Wet Food  1.5% max          40.0       ...
# 3  Dog,Food,Wet Food  1.5% max          97.0       ...
# 4  Dog,Food,Wet Food  1.0% max          33.0       ...
#
#                               price  foodform                 brand       fat  \
# 0  \n                        $21.24  wet food                   NaN  3.5% min
# 1  \n                        $35.99  wet food  hill's, science diet  3.5% min
# 2  \n                        $18.85  wet food                hill's  2.8% min
# 3  \n                        $25.99  wet food       blue wilderness  9.0% min
# 4  \n                        $18.22  wet food                 nutro  5.5% min
#
#                                            breedsize  \
# 0  small breeds, medium breeds, large breeds, all...
# 1  all breeds, small breeds, medium breeds, large...
# 2  all breeds, small breeds, medium breeds, large...
# 3  all breeds, small breeds, medium breeds, large...
# 4                         large breeds, giant breeds
#
#                                          specialdiet  \
# 0                grain-free, no corn no wheat no soy
# 1                                  prescription food
# 2                                                NaN
# 3  grain-free, high-protein, no corn no wheat no soy
# 4                                                NaN
#
#                                             benefits  \
# 0  <li>the best, healthy ingredients from the ear...
# 1  <li>protects vital kidney and heart function w...
# 2  <li>this recipe is made with real meat, brown ...
# 3  <li>made with the finest natural ingredients, ...
# 4  <li>real beef and beef liver in a savory broth...
#
#                                         product_list  \
# 0  whole earth farms grain-free hearty beef stew ...
# 1  hill's prescription diet k/d kidney care chick...
# 2  hill's science diet adult savory stew with bee...
# 3  blue buffalo wilderness duck & chicken grill g...
# 4  nutro max large breed adult beef & rice dinner...
#
#                          maker      foodtexture
# 0         By Whole Earth Farms             stew
# 1  By Hill's Prescription Diet             stew
# 2       By Hill's Science Diet             stew
# 3              By Blue Buffalo             pate
# 4                 By Nutro Max  chunks in gravy
#
# [5 rows x 24 columns]

# %%
wetdog_df=wdog_csv_df[['price','weight','size','product_list']]
wetdog_df.head()
#Check that all Prices include '$'
check_price=all(wetdog_df.price.map(lambda p:bool(re.search('$',str(p)))))
if(check_price):
    wetdog_df['price']=wetdog_df.price.str.replace('\n\s+\$','').str.strip(' ')
else:
    raise('Price Columns incomplete')
wetdog_df.head(12)
# Out:
# C:\Users\cmlim\Anaconda2\envs\py35\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     price         weight                 size  \
# 0   21.24            NaN                  NaN
# 1   35.99            NaN  12.5-oz, case of 12
# 2   18.85            NaN                  NaN
# 3   25.99            NaN                  NaN
# 4   18.22            NaN  12.5-oz, case of 12
# 5   33.99            NaN                  NaN
# 6   30.99            NaN                  NaN
# 7   15.20            NaN                  NaN
# 8   18.96            NaN                  NaN
# 9   24.54            NaN  12.7-oz, case of 12
# 10  33.99            NaN                  NaN
# 11  27.44  10.125 pounds                  NaN
#
#                                          product_list
# 0   whole earth farms grain-free hearty beef stew ...
# 1   hill's prescription diet k/d kidney care chick...
# 2   hill's science diet adult savory stew with bee...
# 3   blue buffalo wilderness duck & chicken grill g...
# 4   nutro max large breed adult beef & rice dinner...
# 5   wellness 95% beef grain-free canned dog food,1...
# 6   purina pro plan veterinary diets nf kidney fun...
# 7   purina one smartblend tender cuts in gravy chi...
# 8   purina pro plan focus adult 7+ beef & rice ent...
# 9   newman's own organics grain-free 95% chicken &...
# 10  wellness turkey & duck stew with sweet potatoe...
# 11  royal canin mature adult in gel canned dog foo...

# %% [markdown]
# ## Collate Weight Column
# Product weight locations lack in uniformity (data structure of website).
# Only a handful products have the weight data correctly stored.
# - Most are located within the Product List columns
# - A handful are within the Size Columns

# %%
wetdog_df2=wetdog_df.copy()
wetdog_df2=wetdog_df2.fillna(0) #Fill NAs with Zero
wetdog_df2.head()
# Out:
#    price weight                 size  \
# 0  21.24      0                    0
# 1  35.99      0  12.5-oz, case of 12
# 2  18.85      0                    0
# 3  25.99      0                    0
# 4  18.22      0  12.5-oz, case of 12
#
#                                         product_list
# 0  whole earth farms grain-free hearty beef stew ...
# 1  hill's prescription diet k/d kidney care chick...
# 2  hill's science diet adult savory stew with bee...
# 3  blue buffalo wilderness duck & chicken grill g...
# 4  nutro max large breed adult beef & rice dinner...

# %% [markdown]
# ### Using Regex Search & Match
# Detect and Include cases of different Keywords ('tub','tray','pounds','oz-case')
# ### Calculate Total Weight (lb)
# Weight(lb)= Oz-per-can * Case Size

# %%
#### Extract Weight & Size ####
#Add Weight and ProductList

for index, row in wetdog_df2.iterrows():
    #print(row['product_list'])
    row['product_list']=re.sub('oz tub,','oz,',row['product_list'])
    row['product_list']=re.sub('oz tray,','oz,',row['product_list'])
    row['product_list']=re.sub('oz case','oz,case',row['product_list'])
    regex=',(\S+)[-| ]oz,case of (\d+)'
    
    #regex_tray=',(\S+)[-| ]oz tray,case of (\d+)'
    if (row['weight']!=0):
        mpd=re.search('(\S+).*pounds', row['weight'])
        moz=re.search('(\S+).*ounces', row['weight'])
        if(bool(mpd)):
            row['weight']=float(mpd.group(1))
        if(bool(moz)):
            row['weight']=float(moz.group(1))*0.0625
    elif((row['size'])!=0):
        regex1='(\S+)-oz, case of (\d+)'
        regex2='(\S+)-lb'
        m1=re.search(regex1,row['size'])
        m2=re.search(regex2,row['size'])
        if(bool(m1)):
            canwt=float(m1.group(1))
            cans=int(m1.group(2))
            row['weight']=canwt*cans*0.0625
        elif(bool(m2)):
            row['weight']=float(m2.group(1))
    else:
        #regex=',(\S+)[-| ]oz,case of (\d+)'
        m=re.search(regex,row['product_list'])
        if(bool(m)):
            canwt=float(m.group(1))
            cans=int(m.group(2))
            row['weight']=canwt*cans*0.0625
        
    regex2='canned dog food'
    row['product_list']=re.sub(regex,'',row['product_list'])
    row['product_list']=re.sub(regex2,'',row['product_list'])
    
wetdog_df2=wetdog_df2.drop('size',axis=1)
wetdog_df2.head()
# Out:
#    price weight                                       product_list
# 0  21.24  9.525     whole earth farms grain-free hearty beef stew
# 1  35.99  9.375  hill's prescription diet k/d kidney care chick...
# 2  18.85    9.6  hill's science diet adult savory stew with bee...
# 3  25.99  9.375  blue buffalo wilderness duck & chicken grill g...
# 4  18.22  9.375  nutro max large breed adult beef & rice dinner...

# %% [markdown]
# ### Clean Maker Column & Generate Brand Column
# - Remove Prefix 'By ' in maker column
# - Consolidate Makers with Multiple Sub-Range to a Single Brand

# %%
wetdog_df2['maker']=wdog_csv_df.maker.map(lambda m: re.sub('By ','',m))

def detect_brand(brand):
    group=['Hill\'s', 'Purina', 'Nutro','Royal Canin']
    brandout=brand
    for grp in group:
        m=re.search(grp,brand)
        if(bool(m)):
           brandout=grp
    return(brandout)
wetdog_df2['brand']=wetdog_df2.maker.map(detect_brand,m)
print(wetdog_df2.brand.unique())
wetdog_df2.head()
# Out:
# ['Whole Earth Farms' "Hill's" 'Blue Buffalo' 'Nutro' 'Wellness' 'Purina'
#  "Newman's Own Organics" 'Royal Canin' 'Holistic Select' 'Pedigree'
#  "Evanger's" 'Dogswell' 'Cesar' "Nature's Logic" 'Nulo' 'Health Extension'
#  'Weruva' 'Eukanuba' 'Natural Balance' 'Instinct' 'Castor & Pollux'
#  'Eagle Pack' 'Party Animal' 'Merrick' 'ALPO' "Nature's Recipe" 'Iams'
#  "Dave's Pet Food" 'CANIDAE' 'PetKind' 'Halo' 'EVO' 'Wild Calling'
#  'Mighty Dog' 'Zignature' 'Chicken Soup' 'Solid Gold' 'Redbarn'
#  'Earthborn Holistic' 'Caru' 'Rachael Ray Nutrish' 'Goody Box'
#  'Taste of the Wild' "Kibbles 'n Bits" 'Precise Holistic Complete'
#  'Tiki Dog' 'Tender & True' 'KASIKS' 'Variety Pet Foods' 'Triumph'
#  'K9 Natural' 'Go!' 'AvoDerm' 'Bravo!' 'PetGuard' 'FirstMate'
#  'Precise Naturals' 'Canine Caviar' 'Nutrisca' 'Under the Sun' 'Evolve'
#  'Hound & Gatos' 'HI-TOR' 'Lotus' 'Wysong' 'Addiction' 'I and Love and You'
#  'Ziwi' 'Gentle Giants' 'Victor' 'Three Dog Bakery' 'Against the Grain'
#  'Tuscan Natural' 'Almo Nature']
#    price weight                                       product_list  \
# 0  21.24  9.525     whole earth farms grain-free hearty beef stew
# 1  35.99  9.375  hill's prescription diet k/d kidney care chick...
# 2  18.85    9.6  hill's science diet adult savory stew with bee...
# 3  25.99  9.375  blue buffalo wilderness duck & chicken grill g...
# 4  18.22  9.375  nutro max large breed adult beef & rice dinner...
#
#                       maker              brand
# 0         Whole Earth Farms  Whole Earth Farms
# 1  Hill's Prescription Diet             Hill's
# 2       Hill's Science Diet             Hill's
# 3              Blue Buffalo       Blue Buffalo
# 4                 Nutro Max              Nutro

# %% [markdown]
# ## Copy over Columns : Rating, Review Count, Food Texture, ID

# %%
wetdog_df2['rating']=wdog_csv_df['rating']
wetdog_df2['review_cnt']=wdog_csv_df['review_count']
wetdog_df2['foodtexture']=wdog_csv_df['foodtexture']
wetdog_df2['id']=wdog_csv_df['itemnumber']
print(wetdog_df2.foodtexture.unique())
wetdog_df2.head()
# Out:
# ['stew' 'pate' 'chunks in gravy' 'minced' 'bits in broth'
#  'pate, chunks in gravy' 'shredded' 'flaked' 'stew, chunks in gravy' nan
#  'bits in broth, pate' 'sliced' 'aspic / gelee' 'ground' 'minced, shredded'
#  'grilled']
#    price weight                                       product_list  \
# 0  21.24  9.525     whole earth farms grain-free hearty beef stew
# 1  35.99  9.375  hill's prescription diet k/d kidney care chick...
# 2  18.85    9.6  hill's science diet adult savory stew with bee...
# 3  25.99  9.375  blue buffalo wilderness duck & chicken grill g...
# 4  18.22  9.375  nutro max large breed adult beef & rice dinner...
#
#                       maker              brand  rating  review_cnt  \
# 0         Whole Earth Farms  Whole Earth Farms     4.4       206.0
# 1  Hill's Prescription Diet             Hill's     4.6       175.0
# 2       Hill's Science Diet             Hill's     4.9        40.0
# 3              Blue Buffalo       Blue Buffalo     4.6        97.0
# 4                 Nutro Max              Nutro     4.6        33.0
#
#        foodtexture     id
# 0             stew  73955
# 1             stew  82589
# 2             stew  52789
# 3             pate  85742
# 4  chunks in gravy  60626

# %% [markdown]
# ## Save Cleaned Dataset for Data Analysis & Visualization

# %%
print(wetdog_df2.shape)
wetdog_df2 = wetdog_df2[wetdog_df2.weight != 0]
print(wetdog_df2.shape)
wetdog_df2.to_csv('wetdogfood_clean.csv')
# Out:
# (1262, 9)
# (1262, 9)

# %% [markdown]
# # Prepping of Scraped Review Data

# %%
wetdogfood_review_df = pd.read_csv('review_wetdogfood.csv')#,encoding="ISO-8859-1",index_col=0)
wetdogfood_review_df.head()
# Out:
#             category                              review_full_content_0  \
# 0  Dog,Food,Wet Food  It is not as stew-y as I expected based on oth...
# 1  Dog,Food,Wet Food  I have two small, picky-eaters and had good lu...
# 2  Dog,Food,Wet Food                                                NaN
# 3  Dog,Food,Wet Food  I had tried another type and brand of this and...
# 4  Dog,Food,Wet Food                                                NaN
#
#                                review_full_content_1  \
# 0  I was surprised my two large dogs didn't like ...
# 1                                                NaN
# 2                                                NaN
# 3  I used to buy one of these rolls every few mon...
# 4                                                NaN
#
#                        pos_review_title  \
# 0           My girls LOVE this food!!!!
# 1  Excellent as a topper for dry kibble
# 2                  My dogs ate this up!
# 3               What a terrific product
# 4                     My dog loves this
#
#                                   pos_review_content  itemnumber  \
# 0  It is not as stew-y as I expected based on oth...       73955
# 1  I have two small, picky-eaters and had good lu...       50640
# 2  My dogs are really finicky, but they lapped th...       60626
# 3  I had tried another type and brand of this and...       76564
# 4  I have not tasted it myself but my Mastiff rea...       84997
#
#                                   neg_review_content                 maker  \
# 0  I was surprised my two large dogs didn't like ...  By Whole Earth Farms
# 1  Selected this food because of the nutritional ...  By Taste of the Wild
# 2  This Was supposed to have Rice with Beef Chunk...          By Nutro Max
# 3  I used to buy one of these rolls every few mon...    By Natural Balance
# 4  Except that this particular variety gave her d...       By Blue Buffalo
#
#                                     neg_review_title
# 0         Surprising  mediocre response from my dogs
# 1                                Didn't do the trick
# 2  Nutro Max Large Breed Adult Beef & Rice Dinner...
# 3    Not the Natural Balance roll of a few years ago
# 4                                  Dog Liked It, But

# %%
pos_review_df=wetdogfood_review_df[['pos_review_content']]
pos_review_df.to_csv('pos_review.csv')
pos_review_df=wetdogfood_review_df[['neg_review_content']]
pos_review_df.to_csv('neg_review.csv')

# %%
pos_title_df=wetdogfood_review_df[['pos_review_title']]
pos_title_df.to_csv('pos_title.csv')
pos_title_df=wetdogfood_review_df[['neg_review_title']]
pos_title_df.to_csv('neg_title.csv')

# %% [markdown]
# ## Clean Key Benefits column

# %%
wdog_csv_df = pd.read_csv('wetdogfood.csv')
wdog_csv_df.head()
wetdog_benefits_df=wdog_csv_df[['benefits']]
wetdog_benefits_df.head()
wetdog_benefits_df['benefits']=wetdog_benefits_df.benefits.map(lambda lines:re.sub('<\S{1,3}>',' ',lines))
wetdog_benefits_df.head()
wetdog_benefits_df.to_csv('benefits.csv')
# Out:
# C:\Users\cmlim\Anaconda2\envs\py35\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
